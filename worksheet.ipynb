# %%
import pandas as pd

# %% [markdown]
# ## Explore the data

# %%
computer_sales = pd.read_csv("computer_sales.csv", sep=',', header=0)

# %% [markdown]
# ## Union computer_sales with computer_sales_2026

# %% [markdown]
# ## Remove Duplicates

# %% [markdown]
# ## Find a solution for the NaN values

# %% [markdown]
# ## Create a column with the number of days since the sale date

# %% [markdown]
# ## Apply one-hot-encoding to the categorical data
